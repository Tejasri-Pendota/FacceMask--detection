# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasri-Pendota/Projects/blob/main/Olympic_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/athlete_events.csv.zip')
region_df = pd.read_csv('/content/drive/MyDrive/noc_regions.csv')

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %%
df = df[df['Season'] == 'Summer']

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
region_df.tail()
# Out:
#      NOC    region        notes
# 225  YEM     Yemen          NaN
# 226  YMD     Yemen  South Yemen
# 227  YUG    Serbia   Yugoslavia
# 228  ZAM    Zambia          NaN
# 229  ZIM  Zimbabwe          NaN

# %%
df = df.merge(region_df, on='NOC', how='left')
##on='NOC': This specifies the column key (or keys) on which the merge should be performed.
# Both df and region_df should have a column named NOC that will be used to align the data between them.

##how='left': This argument specifies the type of merge to perform. A 'left' join means
#that all rows from the left DataFrame (df) will be retained, and matched rows from the right DataFrame (region_df) will be added.
# If there is no match, the result will contain NaN for columns from region_df

# %%
df.tail(5)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 222547  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 222548  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 222549  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 222550  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 222551  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 222547      Argentina  ARG  2004 Summer  2004  Summer          Athina
# 222548  United States  USA  1972 Summer  1972  Summer          Munich
# 222549         Russia  RUS  2000 Summer  2000  Summer          Sydney
# 222550         Russia  RUS  2004 Summer  2004  Summer          Athina
# 222551        Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                                   Event Medal     region  \
# ...

# %%
df['region'].unique()
# Out:
# array(['China', 'Denmark', 'Netherlands', 'Finland', 'Norway', 'Romania',
#        'Estonia', 'France', 'Morocco', 'Spain', 'Egypt', 'Iran',
#        'Bulgaria', 'Italy', 'Chad', 'Azerbaijan', 'Sudan', 'Russia',
#        'Argentina', 'Cuba', 'Belarus', 'Greece', 'Cameroon', 'Turkey',
#        'Chile', 'Mexico', 'USA', 'Nicaragua', 'Hungary', 'Nigeria',
#        'Algeria', 'Kuwait', 'Bahrain', 'Pakistan', 'Iraq', 'Syria',
#        'Lebanon', 'Qatar', 'Malaysia', 'Germany', 'Canada', 'Ireland',
#        'Australia', 'South Africa', 'Eritrea', 'Tanzania', 'Jordan',
#        'Tunisia', 'Libya', 'Belgium', 'Djibouti', 'Palestine', 'Comoros',
#        'Kazakhstan', 'Brunei', 'India', 'Saudi Arabia', 'Maldives',
#        'Ethiopia', 'United Arab Emirates', 'Yemen', 'Indonesia',
#        'Philippines', nan, 'Uzbekistan', 'Kyrgyzstan', 'Tajikistan',
#        'Japan', 'Republic of Congo', 'Switzerland', 'Brazil', 'Monaco',
#        'Israel', 'Uruguay', 'Sweden', 'Sri Lanka', 'Armenia',
# ...

# %%
df['region'].unique().shape
# Out:
# (206,)

# %%
#check duplicates and null values

df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9189
# Height     51857
# Weight     53854
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     188464
# region       370
# notes     218151
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
df.drop_duplicates(inplace =True)
#means that the df DataFrame is modified directly without creating a copy.
#If you want to keep the original DataFrame and create a new one with duplicates dropped,
#use inplace=False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Medal'].value_counts()
# Out:
# Medal
# Gold      11456
# Bronze    11409
# Silver    11212
# Name: count, dtype: int64

# %%
#df = df.merge(region_df, on='NOC', how='left')

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 222547  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 222548  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 222549  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 222550  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 222551  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
df.shape
# Out:
# (221167, 17)

# %%
# Remove duplicate columns by selecting only unique columns
df = df.loc[:, ~df.columns.duplicated()]

print("DataFrame shape after removing duplicates:", df.shape)
# Out:
# DataFrame shape after removing duplicates: (221167, 17)

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 222547  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 222548  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 222549  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 222550  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 222551  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
# List of specific columns to drop
#columns_to_drop = ['Bronze', 'Gold', 'Silver']

# Drop the specific columns
#df = df.drop(columns=columns_to_drop)

#print("DataFrame shape after dropping specific columns:", df.shape)

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 222547  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 222548  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 222549  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 222550  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 222551  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
B_G_S = pd.get_dummies(df['Medal']) #One Hot encoding

# %%
B_G_S = B_G_S.astype('int')
B_G_S
# Out:
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     1       0
# 4            0     0       0
# ...        ...   ...     ...
# 222547       0     0       0
# 222548       0     0       0
# 222549       0     0       0
# 222550       0     0       0
# 222551       0     0       0
#
# [221167 rows x 3 columns]

# %%
# Reset the index of both DataFrames to ensure unique and default integer indices
df = df.reset_index(drop=True)
B_G_S = B_G_S.reset_index(drop=True)

# %%
df = pd.concat([df ,B_G_S], axis=1)
df.head(5)
# Out:
#    ID                                Name Sex   Age  Height  Weight  \
# 0   1                           A Dijiang   M  24.0   180.0    80.0
# 1   2                            A Lamusi   M  23.0   170.0    60.0
# 2   3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3   4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#              Team  NOC        Games  Year  Season         City       Sport  \
# 0           China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1           China  CHN  2012 Summer  2012  Summer       London        Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal       region notes  Bronze  Gold  Silver
# ...

# %%
df.groupby('NOC').sum()[['Gold','Silver','Bronze']].sort_values('Gold' , ascending = False ).reset_index()
# Out:
#      NOC  Gold  Silver  Bronze
# 0    USA  2472    1333    1197
# 1    URS   832     635     596
# 2    GBR   635     729     620
# 3    GER   592     538     649
# 4    ITA   518     474     454
# ..   ...   ...     ...     ...
# 225  MLT     0       0       0
# 226  MLI     0       0       0
# 227  MKD     0       0       1
# 228  MHL     0       0       0
# 229  NFL     0       0       0
#
# [230 rows x 4 columns]

# %% [markdown]
# here the data has the wrong no. of count of medals , its bcz if a team of 5 had won a medal then its considering it as winning 5 medal

# %%
df[(df['NOC'] == 'IND') & (df['Medal'] == 'Gold')]
# Out:
#             ID                    Name Sex   Age  Height  Weight   Team  NOC  \
# 4183      2699             Shaukat Ali   M  30.0     NaN     NaN  India  IND
# 4187      2703        Syed Mushtaq Ali   M  22.0   165.0    61.0  India  IND
# 4454      2864     Richard James Allen   M  25.0   172.0     NaN  India  IND
# 4455      2864     Richard James Allen   M  30.0   172.0     NaN  India  IND
# 4456      2864     Richard James Allen   M  34.0   172.0     NaN  India  IND
# ...        ...                     ...  ..   ...     ...     ...    ...  ...
# 190547  117232      Dung Dung Sylvanus   M  31.0   160.0    62.0  India  IND
# 192751  118553  Carlyle Carrol Tapsell   M  23.0   182.0     NaN  India  IND
# 192752  118553  Carlyle Carrol Tapsell   M  27.0   182.0     NaN  India  IND
# 204699  125560         Max "Maxie" Vaz   M   NaN     NaN     NaN  India  IND
# 217974  133554    Sayed Muhammad Yusuf   M   NaN     NaN     NaN  India  IND
#
# ...

# %%
medal_tally = df.drop_duplicates(subset = ['Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'])

# %%
medal_tally.shape
# Out:
# (105636, 20)

# %%
df.shape
# Out:
# (221167, 20)

# %%
medal_tally = medal_tally.groupby('region').sum()[['Gold','Silver','Bronze']].sort_values('Gold' , ascending = False ).reset_index()

# %%
medal_tally
# Out:
#          region  Gold  Silver  Bronze
# 0           USA  1035     802     708
# 1        Russia   592     498     487
# 2       Germany   444     457     491
# 3            UK   278     317     300
# 4        France   234     256     287
# ..          ...   ...     ...     ...
# 200     Albania     0       0       0
# 201    Kiribati     0       0       0
# 202      Kuwait     0       0       2
# 203  Kyrgyzstan     0       1       2
# 204        Laos     0       0       0
#
# [205 rows x 4 columns]

# %%
years = df['Year'].unique().tolist()
years.sort() # Sort the list in place
years.insert(0, 'Overall')

# %%
years
# Out:
# ['Overall',
#  1896,
#  1900,
#  1904,
#  1906,
#  1908,
#  1912,
#  1920,
#  1924,
#  1928,
#  1932,
#  1936,
#  1948,
#  1952,
#  1956,
#  1960,
#  1964,
#  1968,
#  1972,
#  1976,
#  1980,
#  1984,
#  1988,
#  1992,
#  1996,
#  2000,
#  2004,
#  2008,
#  2012,
#  2016]

# %%
#country = df['region'].dropna().unique()
#country.sort() # Sort the list in place
#country.insert(0, 'Overall')

# %%
#country

# %%
def fetch_medal_tally(df, year, country):
    medal_df = df.drop_duplicates(subset=['Team', 'NOC', 'Games', 'Year', 'City', 'Sport', 'Event', 'Medal'])
    flag = 0
    if year == 'Overall' and country == 'Overall':
        temp_df = medal_df
    if year == 'Overall' and country != 'Overall':
        flag = 1
        temp_df = medal_df[medal_df['region'] == country]
    if year != 'Overall' and country == 'Overall':
        temp_df = medal_df[medal_df['Year'] == int(year)]
    if year != 'Overall' and country != 'Overall':
        temp_df = medal_df[(medal_df['Year'] == year) & (medal_df['region'] == country)]

    if flag == 1:
        x = temp_df.groupby('Year').sum()[['Gold', 'Silver', 'Bronze']].sort_values('Year').reset_index()
    else:
        x = temp_df.groupby('region').sum()[['Gold', 'Silver', 'Bronze']].sort_values('Gold',ascending=False).reset_index()

        return x

# %%
result = fetch_medal_tally( df, year = 2016 , country = 'UK')

# %%
print(result)
# Out:
#   region  Gold  Silver  Bronze
# 0     UK    27      23      17

# %%
df['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array([1992, 2012, 1920, 1900, 1932, 1952, 2000, 1996, 1912, 1924, 1948,
#        2008, 2016, 2004, 1984, 1968, 1972, 1988, 1936, 1956, 1960, 1928,
#        1976, 1980, 1964, 1906, 1904, 1908, 1896])

# %%
df['Name'].unique().shape
# Out:
# (116122,)

# %%
df['region'].unique().shape
# Out:
# (206,)

# %%
df['Event'].unique()
# Out:
# array(["Basketball Men's Basketball", "Judo Men's Extra-Lightweight",
#        "Football Men's Football", "Tug-Of-War Men's Tug-Of-War",
#        "Athletics Women's 100 metres",
#        "Athletics Women's 4 x 100 metres Relay",
#        "Swimming Men's 400 metres Freestyle", "Badminton Men's Singles",
#        "Sailing Women's Windsurfer",
#        "Swimming Men's 200 metres Breaststroke",
#        "Swimming Men's 400 metres Breaststroke",
#        "Gymnastics Men's Individual All-Around",
#        "Gymnastics Men's Team All-Around",
#        "Gymnastics Men's Floor Exercise", "Gymnastics Men's Horse Vault",
#        "Gymnastics Men's Parallel Bars",
#        "Gymnastics Men's Horizontal Bar", "Gymnastics Men's Rings",
#        "Gymnastics Men's Pommelled Horse", "Athletics Men's Shot Put",
#        'Art Competitions Mixed Sculpturing, Unknown Event',
#        "Handball Women's Handball",
#        "Weightlifting Women's Super-Heavyweight",
# ...

# %%
nations_over_time = df.drop_duplicates(["Year" ,"region"])['Year'].value_counts().reset_index().sort_values('Year')

# %%
nations_over_time = nations_over_time.rename(columns = {'Year' : 'Edition' ,'count' : 'No. of Countries'})

# %%
import plotly.express as px

# %%
fig = px.line(nations_over_time , x ="Edition" , y = "No. of Countries")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp_df = df.drop_duplicates(subset = ['Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'])

# %%
new_df = temp_df[temp_df['region'] == 'India']
final_df = new_df.groupby('Year').count()['Medal'].reset_index()

# %%
fig = px.line(final_df , x ="Year" , y = "Medal")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(type(nations_over_time))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
events_over_years = df.drop_duplicates(['Year' , 'Event'])['Year'].value_counts().reset_index().sort_values('Year')

# %%
fig = px.line(events_over_years , x ="Year" , y="count")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def most_sucessful(df, sport):
    temp_df = df.dropna(subset=['Medal'])

    if sport !='Overall' :
       temp_df = temp_df[temp_df['Sport'] == sport]

    x = temp_df['Name'].value_counts().reset_index().merge(df ,left_on ='ID' , right_on ='Name' , how = 'left' )[['ID' ,'Name', 'Sport' ,'region']].drop_duplicates('ID').sort_values('ID' , ascending = False)
    return x

# %%
def most_successful(df, sport):
    temp_df = df.dropna(subset=['Medal'])

    if sport != 'Overall':
        temp_df = temp_df[temp_df['Sport'] == sport]

    x = temp_df['Name'].value_counts().reset_index()
    x = x.head(15).merge(df, left_on='Name', right_on='Name', how='left')[
        ['Name','Medal', 'Sport', 'region']].drop_duplicates('Name')
    return x

# %%
def most_successful(df, sport):
    # Drop rows where 'Medal' is NaN
    temp_df = df.dropna(subset=['Medal'])

    # Filter by sport if it's not 'Overall'
    if sport != 'Overall':
        temp_df = temp_df[temp_df['Sport'] == sport]

    # Count the number of medals each athlete has won
    x = temp_df['Name'].value_counts().reset_index()

    print(x)
    x.columns = ['Name', 'Medal_Count']  # Rename columns for clarity

    # Merge to get additional info like 'Sport' and 'region'
    x = x.merge(df[['Name', 'Sport', 'region']], on='Name', how='left').drop_duplicates('Name')

    return x.head(15)  # Return top 15 athletes

# Usage example
most_successful(df, 'Overall')
# Out:
#                                      Name  count
# 0                 Michael Fred Phelps, II     28
# 1      Larysa Semenivna Latynina (Diriy-)     18
# 2            Nikolay Yefimovich Andrianov     15
# 3                     Edoardo Mangiarotti     13
# 4             Borys Anfiyanovych Shakhlin     13
# ...                                   ...    ...
# 24540                       Iris Zscherpe      1
# 24541                      Ronald Zoodsma      1
# 24542                     Khristos Zorbas      1
# 24543                          Aljoa orga      1
# 24544                        Milenko Zori      1
#
# [24545 rows x 2 columns]
#                                                 Name  Medal_Count       Sport  \
# 0                            Michael Fred Phelps, II           28    Swimming
# 30                Larysa Semenivna Latynina (Diriy-)           18  Gymnastics
# 49                      Nikolay Yefimovich Andrianov           15  Gymnastics
# ...

# %%
 most_successful(df, 'Overall')
# Out:
#                                                 Name  Medal_Count       Sport  \
# 0                            Michael Fred Phelps, II           28    Swimming
# 30                Larysa Semenivna Latynina (Diriy-)           18  Gymnastics
# 49                      Nikolay Yefimovich Andrianov           15  Gymnastics
# 73                               Edoardo Mangiarotti           13     Fencing
# 87                       Borys Anfiyanovych Shakhlin           13  Gymnastics
# 111                                      Takashi Ono           13  Gymnastics
# 144                               Ryan Steven Lochte           12    Swimming
# 158                                       Sawao Kato           12  Gymnastics
# 182             Dara Grace Torres (-Hoffman, -Minas)           12    Swimming
# 195                           Birgit Fischer-Schmidt           12    Canoeing
# 208                    Natalie Anne Coughlin (-Hall)           12    Swimming
# ...

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 221162  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 221163  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 221164  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 221165  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 221166  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...
